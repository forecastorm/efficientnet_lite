# %%
# lite3- int8
repo_path = '/content/efficientnet_lite/'
eval_file_path = repo_path + 'eval_ckpt_main.py'
model_name = 'efficientnet-lite3'
image_dir = '/content/ILSVRC2012_img_val/'
imagenet_eval_glob = image_dir + 'ILSVRC2012*.JPEG'
imagenet_eval_label =  repo_path + 'ground_truth_corrected.txt'
tflite_path = repo_path + 'efficientnet-lite3/efficientnet-lite3-int8.tflite'

# !python $eval_file_path --runmode=imagenet_lite --model_name=$model_name \
--imagenet_eval_glob=$imagenet_eval_glob \
--imagenet_eval_label=$imagenet_eval_label \
--num_images=50000 \
--tflite_path=$tflite_path
# Out:
# 2020-12-19 03:03:02.507834: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-19 03:03:08.145794: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2020-12-19 03:03:08.181066: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2020-12-19 03:03:08.243093: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-12-19 03:03:08.243149: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (426233dbda26): /proc/driver/nvidia/version does not exist
# 2020-12-19 03:03:08.243845: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...
