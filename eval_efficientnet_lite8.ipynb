# %%
repo_path = './'
eval_file_path = repo_path + 'eval_ckpt_main.py'
model_name = 'efficientnet-lite0'
image_dir = '/Volumes/wd/ILSVRC2012_img_val/'
imagenet_eval_glob = image_dir + 'ILSVRC2012*.JPEG'
imagenet_eval_label =  repo_path + 'ground_truth_corrected.txt'
tflite_path = repo_path + 'efficientnet-lite0/efficientnet-lite0-int8.tflite'

# !python $eval_file_path --runmode=imagenet_lite --model_name=$model_name \
--imagenet_eval_glob=$imagenet_eval_glob \
--imagenet_eval_label=$imagenet_eval_label \
--num_images=10 \
--tflite_path=$tflite_path
# Out:
# 2020-12-18 06:55:07.985023: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2020-12-18 06:55:07.985299: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-12-18 06:55:08.045341: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# Traceback (most recent call last):
#   File "./eval_ckpt_main.py", line 140, in <module>
#     app.run(main)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/absl/app.py", line 300, in run
#     _run_main(main, args)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "./eval_ckpt_main.py", line 131, in main
#     driver.eval_imagenet_lite(FLAGS.tflite_path, FLAGS.imagenet_eval_glob,
#   File "/Users/chenjunjie/efficientnet/utils.py", line 726, in eval_imagenet_lite
#     pred_idx, pred_prob=self.run_lite_inference(tflite_path, image_files, labels, enable_ema, export_ckpt)
#   File "/Users/chenjunjie/efficientnet/utils.py", line 611, in run_lite_inference
#     imgs,_ =self.build_dataset(image_files, labels, False)
#   File "/Users/chenjunjie/efficientnet/utils.py", line 489, in build_dataset
#     dataset = dataset.map(_parse_function)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 2630, in map
#     MapDataset(self, map_func, preserve_cardinality=False))
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 4203, in __init__
#     self._map_func = StructuredFunctionWrapper(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 3525, in __init__
#     self._function = wrapper_fn.get_concrete_function()
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3051, in get_concrete_function
#     graph_function = self._get_concrete_function_garbage_collected(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3019, in _get_concrete_function_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 990, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 3518, in wrapper_fn
#     ret = _wrapper_helper(*args)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 3453, in _wrapper_helper
#     ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 670, in wrapper
#     raise e.ag_error_metadata.to_exception(e)
# tensorflow.python.framework.errors_impl.InvalidArgumentError: in user code:
#
#     /Users/chenjunjie/efficientnet/utils.py:478 _parse_function  *
#         print(image_string.eval())
#     /Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:921 eval  **
#         return _eval_using_default_session(self, feed_dict, self.graph, session)
#     /Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:5512 _eval_using_default_session
#         return session.run(tensors, feed_dict)
#     /Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/client/session.py:967 run
#         result = self._run(None, fetches, feed_dict, options_ptr,
#     /Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/client/session.py:1190 _run
#         results = self._do_run(handle, final_targets, final_fetches,
#     /Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/client/session.py:1368 _do_run
#         return self._do_call(_run_fn, feeds, fetches, targets, options,
#     /Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/client/session.py:1394 _do_call
#         raise type(e)(node_def, op, message)
#
#     InvalidArgumentError: You must feed a value for placeholder tensor 'args_0' with dtype string
#     	 [[node args_0 (defined at /Users/chenjunjie/efficientnet/utils.py:489) ]]
#
#     Original stack trace for 'args_0':
#       File "./eval_ckpt_main.py", line 140, in <module>
#         app.run(main)
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/absl/app.py", line 300, in run
#         _run_main(main, args)
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/absl/app.py", line 251, in _run_main
#         sys.exit(main(argv))
#       File "./eval_ckpt_main.py", line 131, in main
#         driver.eval_imagenet_lite(FLAGS.tflite_path, FLAGS.imagenet_eval_glob,
#       File "/Users/chenjunjie/efficientnet/utils.py", line 726, in eval_imagenet_lite
#         pred_idx, pred_prob=self.run_lite_inference(tflite_path, image_files, labels, enable_ema, export_ckpt)
#       File "/Users/chenjunjie/efficientnet/utils.py", line 611, in run_lite_inference
#         imgs,_ =self.build_dataset(image_files, labels, False)
#       File "/Users/chenjunjie/efficientnet/utils.py", line 489, in build_dataset
#         dataset = dataset.map(_parse_function)
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 2630, in map
#         MapDataset(self, map_func, preserve_cardinality=False))
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 4203, in __init__
#         self._map_func = StructuredFunctionWrapper(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 3525, in __init__
#         self._function = wrapper_fn.get_concrete_function()
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3051, in get_concrete_function
#         graph_function = self._get_concrete_function_garbage_collected(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3019, in _get_concrete_function_garbage_collected
#         graph_function, _ = self._maybe_define_function(args, kwargs)
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3361, in _maybe_define_function
#         graph_function = self._create_graph_function(args, kwargs)
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#         func_graph_module.func_graph_from_py_func(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 906, in func_graph_from_py_func
#         func_args = _get_defun_inputs_from_args(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1142, in _get_defun_inputs_from_args
#         return _get_defun_inputs(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1215, in _get_defun_inputs
#         placeholder = graph_placeholder(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/graph_only_ops.py", line 38, in graph_placeholder
#         op = g._create_op_internal(  # pylint: disable=protected-access
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 590, in _create_op_internal
#         return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 3528, in _create_op_internal
#         ret = Operation(
#       File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 1990, in __init__
#         self._traceback = tf_stack.extract_stack()
#
#
#
# Original stack trace for 'args_0':
#   File "./eval_ckpt_main.py", line 140, in <module>
#     app.run(main)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/absl/app.py", line 300, in run
#     _run_main(main, args)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "./eval_ckpt_main.py", line 131, in main
#     driver.eval_imagenet_lite(FLAGS.tflite_path, FLAGS.imagenet_eval_glob,
#   File "/Users/chenjunjie/efficientnet/utils.py", line 726, in eval_imagenet_lite
#     pred_idx, pred_prob=self.run_lite_inference(tflite_path, image_files, labels, enable_ema, export_ckpt)
#   File "/Users/chenjunjie/efficientnet/utils.py", line 611, in run_lite_inference
#     imgs,_ =self.build_dataset(image_files, labels, False)
#   File "/Users/chenjunjie/efficientnet/utils.py", line 489, in build_dataset
#     dataset = dataset.map(_parse_function)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 2630, in map
#     MapDataset(self, map_func, preserve_cardinality=False))
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 4203, in __init__
#     self._map_func = StructuredFunctionWrapper(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 3525, in __init__
#     self._function = wrapper_fn.get_concrete_function()
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3051, in get_concrete_function
#     graph_function = self._get_concrete_function_garbage_collected(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3019, in _get_concrete_function_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3361, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3196, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 906, in func_graph_from_py_func
#     func_args = _get_defun_inputs_from_args(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1142, in _get_defun_inputs_from_args
#     return _get_defun_inputs(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 1215, in _get_defun_inputs
#     placeholder = graph_placeholder(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/eager/graph_only_ops.py", line 38, in graph_placeholder
#     op = g._create_op_internal(  # pylint: disable=protected-access
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 590, in _create_op_internal
#     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 3528, in _create_op_internal
#     ret = Operation(
#   File "/Users/chenjunjie/efficientnet/venv/lib/python3.8/site-packages/tensorflow/python/framework/ops.py", line 1990, in __init__
#     self._traceback = tf_stack.extract_stack()
